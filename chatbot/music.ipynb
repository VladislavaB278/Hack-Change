# %%
# %pip install numpy 
# %pip install pandas
# %pip install torch
# %pip install torchaudio
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h1>HACK&CHANGE</h1>
# <h2>ChatBot</h2>

# %%
import numpy as np
import pandas as pd
import torchaudio
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Recommend system</h3>
# <h4>Система рекомендации будет основываться на мел-частотно кепстральных коэффициентах, что обеспечит подбор наиболее похожей музыки</h4>

# %%
class Music(): 
    music : str

# %%
music_ex = Music()
music_ex.music = '/home/knyazev_artem/recommendation_system/test_content/fed_up.wav'

# %%
# Загрузка аудиофайла
waveform, sample_rate = torchaudio.load(music_ex.music)

# %%
mfccs = torchaudio.compliance.kaldi.mfcc(waveform, sample_rate) 
print(mfccs.numpy()) #Вывод мел-частотно кепстральных коэффициентов в виде массива numpy
# Out:
# [[-71.38031    -13.499572     6.4471755  ...   6.9589663   -0.9105819
#    -5.2033935 ]
#  [-72.05867    -12.50623      8.663096   ...   1.8006401    1.285029
#    -3.6659591 ]
#  [-71.64216    -13.0902       6.7754326  ...   2.7580194    0.21380143
#    -1.9565498 ]
#  ...
#  [-71.450356   -14.0402155    8.857543   ...   0.60053855   2.03026
#    -1.0803363 ]
#  [-71.76001    -13.500145     9.858867   ...   2.873656     0.5660217
#    -1.988073  ]
#  [-71.9601     -13.455944    11.383329   ...   1.9242806    1.9580848
#    -4.194332  ]]

# %%
plt.figure()
plt.plot(mfccs.log2().numpy()) # построение спектрограммы 
plt.show()

# %%
# %pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.spatial import distance

# рассчитываем Евклидово расстояние между показателями мел-частотно кепстральных коэффициентов двух песен 
similarity = distance.euclidean(mfccs1, mfccs2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/knyazev_artem/recommendation_system/recomendation_system/music.ipynb Cell 8 line 4
#       <a href='vscode-notebook-cell:/home/knyazev_artem/recommendation_system/recomendation_system/music.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> from scipy.spatial import distance
#       <a href='vscode-notebook-cell:/home/knyazev_artem/recommendation_system/recomendation_system/music.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> # Calculate the Euclidean distance between the MFCCs of two songs
# ----> <a href='vscode-notebook-cell:/home/knyazev_artem/recommendation_system/recomendation_system/music.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> similarity = distance.euclidean(mfccs1, mfccs2)
#
# NameError: name 'mfccs1' is not defined

# %%
# Select the top N songs with the smallest similarity scores
similar_songs = sorted(songs, key=lambda song: distance.euclidean(song['mfccs'], target_song['mfccs']))[:N]
